# %%
from simulator import HathorSimulator, Miner
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats

# %%
sim = HathorSimulator(block_weight=12)

m0 = Miner(hashpower=100000)
sim.add_miner(m0)

# %%
sim.run(3600*24*30)
print('block weight', sim.block_weight)
# Out:
# [       80.09] Weight updated: blocks= 2015 dt= 80.09  12.00 ->  23.65
# [   261248.69] Weight updated: blocks= 4031 dt=261168.60  23.65 ->  23.64
# [   534116.04] Weight updated: blocks= 6047 dt=272867.35  23.64 ->  23.56
# [   793433.22] Weight updated: blocks= 8063 dt=259317.18  23.56 ->  23.55
# [  1043013.05] Weight updated: blocks=10079 dt=249579.83  23.55 ->  23.60
# [  1292566.11] Weight updated: blocks=12095 dt=249553.06  23.60 ->  23.65
# [  1557627.63] Weight updated: blocks=14111 dt=265061.52  23.65 ->  23.61
# [  1814090.82] Weight updated: blocks=16127 dt=256463.19  23.61 ->  23.62
# [  2084949.63] Weight updated: blocks=18143 dt=270858.81  23.62 ->  23.55
# [  2336068.15] Weight updated: blocks=20159 dt=251118.52  23.55 ->  23.58
# ('block weight', 23.584746251226562)

# %%
prev = None
v = []
for x in sim.blocks[4000:20000]:
    if prev is None:
        prev = x
    else:
        v.append(x.time - prev.time)
        prev = x

# %%
plt.figure(figsize=(8, 6), dpi=300)
plt.hist(v, bins='fd', density=True);

x = np.linspace(0, max(v), 1000)
y = scipy.stats.expon.pdf(x, 0, 128)
plt.plot(x, y, 'r', linewidth=2);

plt.ylabel('Histogram')
plt.xlabel('Time between blocks with one miner');

plt.xlim(0, 800);

# %%
print('---- Adding another miner')
m1 = Miner(hashpower=500000)
sim.add_miner(m1)
# Out:
# ---- Adding another miner

# %%
sim.run(3600*24*30)
print('block weight', sim.block_weight)
# Out:
# [  2592055.16] Weight updated: blocks=22175 dt=255987.01  23.58 ->  23.60
# [  2634318.83] Weight updated: blocks=24191 dt=42263.67  23.60 ->  26.21
# [  2891292.00] Weight updated: blocks=26207 dt=256973.17  26.21 ->  26.21
# [  3143868.99] Weight updated: blocks=28223 dt=252576.98  26.21 ->  26.24
# [  3413848.29] Weight updated: blocks=30239 dt=269979.31  26.24 ->  26.18
# [  3671637.21] Weight updated: blocks=32255 dt=257788.92  26.18 ->  26.18
# [  3928262.56] Weight updated: blocks=34271 dt=256625.35  26.18 ->  26.19
# [  4178272.05] Weight updated: blocks=36287 dt=250009.49  26.19 ->  26.23
# [  4437484.75] Weight updated: blocks=38303 dt=259212.69  26.23 ->  26.23
# [  4698854.47] Weight updated: blocks=40319 dt=261369.73  26.23 ->  26.21
# [  4971158.65] Weight updated: blocks=42335 dt=272304.18  26.21 ->  26.13
# ('block weight', 26.130745525653243)

# %%
prev = None
v = []
for x in sim.blocks[25000:40000]:
    if prev is None:
        prev = x
    else:
        v.append(x.time - prev.time)
        prev = x

# %%
plt.figure(figsize=(8, 6), dpi=300)
plt.hist(v, bins='fd', density=True);

x = np.linspace(0, max(v), 1000)
y = scipy.stats.expon.pdf(x, 0, 128)
plt.plot(x, y, 'r', linewidth=2);

plt.ylabel('Histogram')
plt.xlabel('Time between blocks with two miners after update');

plt.xlim(0, 800);

# %%
sim.remove_miner(m1)

# %%
sim.run(3600*24*30)
print('block weight', sim.block_weight)
# Out:
# [  5401513.28] Weight updated: blocks=44351 dt=430354.63  26.13 ->  25.39
# [  6276798.90] Weight updated: blocks=46367 dt=875285.62  25.39 ->  23.63
# [  6540839.50] Weight updated: blocks=48383 dt=264040.60  23.63 ->  23.60
# [  6799654.58] Weight updated: blocks=50399 dt=258815.08  23.60 ->  23.59
# [  7051802.33] Weight updated: blocks=52415 dt=252147.74  23.59 ->  23.63
# [  7312199.37] Weight updated: blocks=54431 dt=260397.04  23.63 ->  23.61
# [  7564525.27] Weight updated: blocks=56447 dt=252325.90  23.61 ->  23.65
# ('block weight', 23.645989663942355)

# %%
prev = None
v = []
for x in sim.blocks[49000:55000]:
    if prev is None:
        prev = x
    else:
        v.append(x.time - prev.time)
        prev = x

# %%
plt.figure(figsize=(8, 6), dpi=300)
plt.hist(v, bins='fd', density=True);

x = np.linspace(0, max(v), 1000)
y = scipy.stats.expon.pdf(x, 0, 128)
plt.plot(x, y, 'r', linewidth=2);

plt.ylabel('Histogram')
plt.xlabel('Time between blocks');

plt.xlim(0, 800);
